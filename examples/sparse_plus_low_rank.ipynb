# %% [markdown]
# # <center>Compressing Influence Matrix Using Sparse Plus Low Rank</center>
#
# The dose influence matrix is a fundamental component in the optimization process, but its handling can introduce computational challenges. The original matrix, being dense, requires substantial computational resources to manage. Hence, sparse influence matrix is being used in planning acorss various TPS to avoid computational issue. But it often leads to sub-optimal solutions, thus comprimising accuracy and plan quality. Hence we introduce novel technique of compressing original dense matrix using sparse plus low rank technique
#
# 1. Generating a plan utilizing the sparse matrix with naive threshold of 1% of max(A)
# 2. Compressed planning using Sparse plus low rank method
# 3. Visualizing and evaluating plan

# %% [markdown]
# ### 1) Generating a plan utilizing the sparse matrix

# %%
# !pip install -r requirements.txt

# %%
import sys
sys.path.append('../../PortPy')
sys.path.append('../')

# %%
import portpy.photon as pp
from compress_rtp.compress_rtp_optimization import CompressRTPOptimization
import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
import scipy

# %%
# specify the patient data location.
data_dir = r'../../PortPy/data'
# Use PortPy DataExplorer class to explore PortPy data
data = pp.DataExplorer(data_dir=data_dir)

# pick a patient from the existing patient list to get detailed info (e.g., beam angles, structures).
data.patient_id = 'Lung_Patient_6'

ct = pp.CT(data)
structs = pp.Structures(data)

# If the list of beams are not provided, it uses the beams selected manually
# by a human expert planner for the patient (manually selected beams are stored in portpy data).
# Create beams for the planner beams by default
# for the customized beams, you can pass the argument beam_ids
# e.g. beams = pp.Beams(data, beam_ids=[0,10,20,30,40,50,60])
beams = pp.Beams(data, load_inf_matrix_full=True)

# In order to create an IMRT plan, we first need to specify a protocol which includes the disease site,
# the prescribed dose for the PTV, the number of fractions, and the radiation dose thresholds for OARs.
# These information are stored in .json files which can be found in a directory named "config_files".
# An example of such a file is 'Lung_2Gy_30Fx.json'. Here's how you can load these files:
protocol_name = 'Lung_2Gy_30Fx'
# load clinical criteria from the config files for which plan to be optimized
clinical_criteria = pp.ClinicalCriteria(data, protocol_name=protocol_name)

# Optimization problem formulation
protocol_name = 'Lung_2Gy_30Fx'
# Loading hyper-parameter values for optimization problem
opt_params = data.load_config_opt_params(protocol_name=protocol_name)
# Creating optimization structures (i.e., Rinds)
structs.create_opt_structures(opt_params=opt_params, clinical_criteria=clinical_criteria)
# Loading influence matrix
inf_matrix = pp.InfluenceMatrix(ct=ct, structs=structs, beams=beams, is_full=True)

# create a plan using ct, structures, beams and influence matrix. Clinical criteria is optional
my_plan = pp.Plan(ct=ct, structs=structs, beams=beams, inf_matrix=inf_matrix, clinical_criteria=clinical_criteria)
# Out:
# Creating optimization structures.. It may take some time due to dilation
# Optimization structures created!!
# Creating BEV..
# Loading full influence matrix..
# Done

# %%
# run optimization with naive thresold of 1% of max(A) and no low rank
# create cvxpy problem using the clinical criteria and optimization parameters
A = deepcopy(inf_matrix.A)
tol = np.max(A) * 1 * 0.01
S = np.where(A > tol, A, 0)
S = scipy.sparse.csr_matrix(S)
inf_matrix.A = S

# %%
opt = pp.Optimization(my_plan, inf_matrix=inf_matrix, opt_params=opt_params)
opt.create_cvxpy_problem()
sol_sparse = opt.solve(solver='MOSEK', verbose=True)
# Out:
# Objective Start
# Objective done
# Constraints Start
# Constraints done
# Running Optimization..
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Sep 29 01:48:55 PM: Your problem has 9574 variables, 18 constraints, and 0 parameters.
# (CVXPY) Sep 29 01:48:55 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 29 01:48:55 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 29 01:48:55 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 29 01:48:55 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Sep 29 01:48:55 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Sep 29 01:48:55 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 29 01:48:55 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 29 01:48:55 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 29 01:49:19 PM: Applying reduction MOSEK
# (CVXPY) Sep 29 01:49:29 PM: Finished problem compilation (took 3.416e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 29 01:49:29 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Sep 29 01:49:39 PM: Problem
# (CVXPY) Sep 29 01:49:39 PM:   Name                   :
# (CVXPY) Sep 29 01:49:39 PM:   Objective sense        : maximize
# (CVXPY) Sep 29 01:49:39 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Sep 29 01:49:39 PM:   Constraints            : 9589
# (CVXPY) Sep 29 01:49:39 PM:   Affine conic cons.     : 0
# (CVXPY) Sep 29 01:49:39 PM:   Disjunctive cons.      : 0
# (CVXPY) Sep 29 01:49:39 PM:   Cones                  : 15
# (CVXPY) Sep 29 01:49:39 PM:   Scalar variables       : 1199843
# (CVXPY) Sep 29 01:49:39 PM:   Matrix variables       : 0
# (CVXPY) Sep 29 01:49:39 PM:   Integer variables      : 0
# (CVXPY) Sep 29 01:49:39 PM:
# (CVXPY) Sep 29 01:49:39 PM: Optimizer started.
# (CVXPY) Sep 29 01:49:41 PM: Presolve started.
# (CVXPY) Sep 29 01:49:43 PM: Linear dependency checker started.
# (CVXPY) Sep 29 01:49:44 PM: Linear dependency checker terminated.
# (CVXPY) Sep 29 01:49:44 PM: Eliminator started.
# (CVXPY) Sep 29 01:49:45 PM: Freed constraints in eliminator : 0
# (CVXPY) Sep 29 01:49:45 PM: Eliminator terminated.
# (CVXPY) Sep 29 01:49:45 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Sep 29 01:49:45 PM: Lin. dep.  - tries                  : 1                 time                   : 0.22
# (CVXPY) Sep 29 01:49:45 PM: Lin. dep.  - number                 : 0
# (CVXPY) Sep 29 01:49:45 PM: Presolve terminated. Time: 4.08
# (CVXPY) Sep 29 01:49:50 PM: Problem
# (CVXPY) Sep 29 01:49:50 PM:   Name                   :
# (CVXPY) Sep 29 01:49:50 PM:   Objective sense        : maximize
# (CVXPY) Sep 29 01:49:50 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Sep 29 01:49:50 PM:   Constraints            : 9589
# (CVXPY) Sep 29 01:49:50 PM:   Affine conic cons.     : 0
# (CVXPY) Sep 29 01:49:50 PM:   Disjunctive cons.      : 0
# (CVXPY) Sep 29 01:49:50 PM:   Cones                  : 15
# (CVXPY) Sep 29 01:49:50 PM:   Scalar variables       : 1199843
# (CVXPY) Sep 29 01:49:50 PM:   Matrix variables       : 0
# (CVXPY) Sep 29 01:49:50 PM:   Integer variables      : 0
# (CVXPY) Sep 29 01:49:50 PM:
# (CVXPY) Sep 29 01:49:50 PM: Optimizer  - threads                : 16
# (CVXPY) Sep 29 01:49:50 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Sep 29 01:49:50 PM: Optimizer  - Constraints            : 9589
# (CVXPY) Sep 29 01:49:50 PM: Optimizer  - Cones                  : 15
# (CVXPY) Sep 29 01:49:50 PM: Optimizer  - Scalar variables       : 545424            conic                  : 349066
# (CVXPY) Sep 29 01:49:50 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Sep 29 01:49:50 PM: Factor     - setup time             : 3.89              dense det. time        : 0.00
# (CVXPY) Sep 29 01:49:50 PM: Factor     - ML order time          : 0.78              GP order time          : 0.00
# (CVXPY) Sep 29 01:49:50 PM: Factor     - nonzeros before factor : 2.87e+06          after factor           : 2.87e+06
# (CVXPY) Sep 29 01:49:50 PM: Factor     - dense dim.             : 4                 flops                  : 2.52e+09
# (CVXPY) Sep 29 01:49:50 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY)
# (CVXPY) Sep 29 01:50:03 PM: 19  5.7e-05  4.9e-03  2.6e-06  1.00e+00   9.140374241e+01   9.140070021e+01   2.4e-06  23.50
# (CVXPY) Sep 29 01:50:03 PM: 20  2.0e-05  1.7e-03  5.3e-07  1.00e+00   5.934612120e+01   5.934507005e+01   8.1e-07  24.22
# (CVXPY) Sep 29 01:50:04 PM: 21  1.2e-05  1.0e-03  2.6e-07  1.00e+00   5.327100702e+01   5.327035660e+01   5.0e-07  24.83
# (CVXPY) Sep 29 01:50:05 PM: 22  5.9e-06  5.0e-04  8.6e-08  1.00e+00   4.850747911e+01   4.850716185e+01   2.4e-07  25.39
# (CVXPY) Sep 29 01:50:05 PM: 23  1.8e-06  1.5e-04  1.4e-08  9.99e-01   4.542555692e+01   4.542546068e+01   7.3e-08  26.02
# (CVXPY) Sep 29 01:50:06 PM: 24  2.5e-07  2.2e-05  7.7e-10  9.99e-01   4.443668779e+01   4.443667417e+01   1.0e-08  27.25
# (CVXPY) Sep 29 01:50:07 PM: 25  5.6e-08  4.8e-06  8.1e-11  1.00e+00   4.431771378e+01   4.431771075e+01   2.3e-09  27.88
# (CVXPY) Sep 29 01:50:08 PM: 26  1.8e-08  1.6e-06  1.5e-11  9.98e-01   4.429638083e+01   4.429637983e+01   7.6e-10  28.58
# (CVXPY) Sep 29 01:50:10 PM: 27  6.6e-09  5.6e-07  3.2e-12  1.00e+00   4.428852298e+01   4.428852263e+01   2.7e-10  30.45
# (CVXPY) Sep 29 01:50:11 PM: 28  4.3e-09  5.6e-07  1.7e-12  9.76e-01   4.428735784e+01   4.428735761e+01   1.7e-10  31.72
# (CVXPY) Sep 29 01:50:11 PM: Optimizer terminated. Time: 32.34
# (CVXPY) Sep 29 01:50:11 PM:
# (CVXPY) Sep 29 01:50:11 PM:
# (CVXPY) Sep 29 01:50:11 PM: Interior-point solution summary
# (CVXPY) Sep 29 01:50:11 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Sep 29 01:50:11 PM:   Solution status : OPTIMAL
# (CVXPY) Sep 29 01:50:12 PM:   Primal.  obj: 4.4287357841e+01    nrm: 3e+01    Viol.  con: 8e-07    var: 2e-05    cones: 0e+00
# (CVXPY) Sep 29 01:50:12 PM:   Dual.    obj: 4.4287357609e+01    nrm: 4e+04    Viol.  con: 0e+00    var: 2e-08    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 29 01:50:12 PM: Problem status: optimal
# (CVXPY) Sep 29 01:50:12 PM: Optimal value: 4.429e+01
# (CVXPY) Sep 29 01:50:12 PM: Compilation took 3.416e+01 seconds
# (CVXPY) Sep 29 01:50:12 PM: Solver (including time spent in interface) took 4.260e+01 seconds
# Optimal value: 44.287151316788844
# Elapsed time: 77.26874542236328 seconds

# %% [markdown]
# ### 2) Generating plan ustilizing compression of Influence Matrix using Sparse plus low rank

# %% [markdown]
# Instead of optimizing the plan using sparse influence matrix $ S $ we optimize it using sparse plus low rank of small values of dense influence matrix $L = A-S$, which is given by,
# $
# \mbox{Minimize}: f(S\mathbf{x} + HW\mathbf{x})\\
# \mbox{s.t}
# \quad \quad h(S\mathbf{x} + HW\mathbf{x}) \leq 0
# $

# %%
# run optimization with thresold of 1% and rank 5
# create cvxpy problem using the clinical criteria and optimization parameters
opt = CompressRTPOptimization(my_plan, opt_params=opt_params)
S, H, W = opt.get_sparse_plus_low_rank(A=A, thresold_perc=1, rank=5)
# Out:
# Running svd..
# svd done!

# %%
opt.create_cvxpy_problem_compressed(S=S, H=H, W=W)
# run imrt fluence map optimization using cvxpy and one of the supported solvers and save the optimal solution in sol_slr
mosek_params={'MSK_IPAR_PRESOLVE_ELIMINATOR_MAX_NUM_TRIES': 0,
                          'MSK_IPAR_INTPNT_SCALING': 'MSK_SCALING_NONE'}
sol_slr = opt.solve(solver='MOSEK', verbose=True, mosek_params=mosek_params)
# Out:
# Objective Start
# Objective done
# Constraints Start
# Constraints done
# Running Optimization..
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Sep 29 01:50:31 PM: Your problem has 9579 variables, 19 constraints, and 0 parameters.
# (CVXPY) Sep 29 01:50:31 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 29 01:50:31 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 29 01:50:31 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 29 01:50:31 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Sep 29 01:50:31 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Sep 29 01:50:31 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 29 01:50:31 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 29 01:50:31 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 29 01:51:03 PM: Applying reduction MOSEK
# (CVXPY) Sep 29 01:51:15 PM: Finished problem compilation (took 4.404e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 29 01:51:15 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Sep 29 01:51:27 PM: Problem
# (CVXPY) Sep 29 01:51:27 PM:   Name                   :
# (CVXPY) Sep 29 01:51:27 PM:   Objective sense        : maximize
# (CVXPY) Sep 29 01:51:27 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Sep 29 01:51:27 PM:   Constraints            : 9594
# (CVXPY) Sep 29 01:51:27 PM:   Affine conic cons.     : 0
# (CVXPY) Sep 29 01:51:27 PM:   Disjunctive cons.      : 0
# (CVXPY) Sep 29 01:51:27 PM:   Cones                  : 15
# (CVXPY) Sep 29 01:51:27 PM:   Scalar variables       : 1199848
# (CVXPY) Sep 29 01:51:27 PM:   Matrix variables       : 0
# (CVXPY) Sep 29 01:51:27 PM:   Integer variables      : 0
# (CVXPY) Sep 29 01:51:27 PM:
# (CVXPY) Sep 29 01:51:27 PM: Optimizer started.
# (CVXPY) Sep 29 01:51:29 PM: Presolve started.
# (CVXPY) Sep 29 01:51:32 PM: Linear dependency checker started.
# (CVXPY) Sep 29 01:51:32 PM: Linear dependency checker terminated.
# (CVXPY) Sep 29 01:51:32 PM: Eliminator - tries                  : 0                 time                   : 0.00
# (CVXPY) Sep 29 01:51:32 PM: Lin. dep.  - tries                  : 1                 time                   : 0.23
# (CVXPY) Sep 29 01:51:32 PM: Lin. dep.  - number                 : 0
# (CVXPY) Sep 29 01:51:32 PM: Presolve terminated. Time: 3.34
# (CVXPY) Sep 29 01:51:38 PM: Problem
# (CVXPY) Sep 29 01:51:38 PM:   Name                   :
# (CVXPY) Sep 29 01:51:38 PM:   Objective sense        : maximize
# (CVXPY) Sep 29 01:51:38 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Sep 29 01:51:38 PM:   Constraints            : 9594
# (CVXPY) Sep 29 01:51:38 PM:   Affine conic cons.     : 0
# (CVXPY) Sep 29 01:51:38 PM:   Disjunctive cons.      : 0
# (CVXPY) Sep 29 01:51:38 PM:   Cones                  : 15
# (CVXPY) Sep 29 01:51:38 PM:   Scalar variables       : 1199848
# (CVXPY) Sep 29 01:51:38 PM:   Matrix variables       : 0
# (CVXPY) Sep 29 01:51:38 PM:   Integer variables      : 0
# (CVXPY) Sep 29 01:51:38 PM:
# (CVXPY) Sep 29 01:51:38 PM: Optimizer  
PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Sep 29 01:52:14 PM:   Solution status : OPTIMAL
# (CVXPY) Sep 29 01:52:14 PM:   Primal.  obj: 4.1224901721e+01    nrm: 3e+01    Viol.  con: 1e-07    var: 6e-10    cones: 0e+00
# (CVXPY) Sep 29 01:52:14 PM:   Dual.    obj: 4.1224901752e+01    nrm: 4e+04    Viol.  con: 0e+00    var: 6e-09    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 29 01:52:15 PM: Problem status: optimal
# (CVXPY) Sep 29 01:52:15 PM: Optimal value: 4.122e+01
# (CVXPY) Sep 29 01:52:15 PM: Compilation took 4.404e+01 seconds
# (CVXPY) Sep 29 01:52:15 PM: Solver (including time spent in interface) took 5.848e+01 seconds
# Optimal value: 41.224899428002594
# Elapsed time: 103.10168743133545 seconds

# %% [markdown]
# ### 3) Visualizing and evaluate plan with and without compression

# %%
fig, ax = plt.subplots(figsize=(12, 8))
struct_names = ['PTV', 'ESOPHAGUS', 'HEART', 'CORD', 'LUNGS_NOT_GTV']
dose_1d_sparse = (S @ sol_sparse['optimal_intensity']) * my_plan.get_num_of_fractions()
dose_1d_full = (A @ sol_sparse['optimal_intensity']) * my_plan.get_num_of_fractions()
ax = pp.Visualization.plot_dvh(my_plan, dose_1d=dose_1d_sparse, struct_names=struct_names, style='dotted', ax=ax, norm_flag=True)
ax = pp.Visualization.plot_dvh(my_plan, dose_1d=dose_1d_full, struct_names=struct_names, style='solid', ax=ax, norm_flag=True)
ax.set_title("sparse_vs_full")
plt.show(block=False)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
struct_names = ['PTV', 'ESOPHAGUS', 'HEART', 'CORD', 'LUNGS_NOT_GTV']
dose_1d_slr = (S @ sol_slr['optimal_intensity'] + H @ (W @ sol_slr['optimal_intensity'])) * my_plan.get_num_of_fractions()
dose_1d_full = (A @ sol_slr['optimal_intensity']) * my_plan.get_num_of_fractions()
ax = pp.Visualization.plot_dvh(my_plan, dose_1d=dose_1d_slr, struct_names=struct_names, style='dashed', ax=ax, norm_flag=True)
ax = pp.Visualization.plot_dvh(my_plan, dose_1d=dose_1d_full, struct_names=struct_names, style='solid', ax=ax, norm_flag=True)
ax.set_title("slr_vs_full")
plt.show(block=False)

# %%
# visualize plan metrics based upon clinical criteria
pp.Evaluation.display_clinical_criteria(my_plan, dose_1d=[dose_1d_sparse, dose_1d_slr], sol_names=['Without compression', 'With compression')
# Out:
# Warning: dose_1d value 60.0 is greater than max dose_1d for ESOPHAGUS
# Warning: dose_1d value 60.0 is greater than max dose_1d for ESOPHAGUS
# <style type="text/css">
# #T_f717e_row0_col0, #T_f717e_row0_col1, #T_f717e_row0_col2, #T_f717e_row0_col3, #T_f717e_row1_col0, #T_f717e_row1_col1, #T_f717e_row1_col2, #T_f717e_row1_col3, #T_f717e_row2_col0, #T_f717e_row2_col1, #T_f717e_row2_col2, #T_f717e_row2_col3, #T_f717e_row3_col0, #T_f717e_row3_col1, #T_f717e_row3_col2, #T_f717e_row3_col3, #T_f717e_row4_col0, #T_f717e_row4_col1, #T_f717e_row4_col2, #T_f717e_row4_col3, #T_f717e_row5_col0, #T_f717e_row5_col1, #T_f717e_row5_col2, #T_f717e_row5_col3, #T_f717e_row6_col0, #T_f717e_row6_col1, #T_f717e_row6_col2, #T_f717e_row6_col3, #T_f717e_row7_col0, #T_f717e_row7_col1, #T_f717e_row7_col2, #T_f717e_row7_col3, #T_f717e_row8_col0, #T_f717e_row8_col1, #T_f717e_row8_col2, #T_f717e_row8_col3, #T_f717e_row9_col0, #T_f717e_row9_col1, #T_f717e_row9_col2, #T_f717e_row9_col3, #T_f717e_row10_col0, #T_f717e_row10_col1, #T_f717e_row10_col2, #T_f717e_row10_col3, #T_f717e_row11_col0, #T_f717e_row11_col1, #T_f717e_row11_col2, #T_f717e_row11_col3, #T_f717e_row12_col0, #T_f717e_row12_col1, #T_f717e_row12_col2, #T_f717e_row12_col3, #T_f717e_row13_col0, #T_f717e_row13_col1, #T_f717e_row13_col2, #T_f717e_row13_col3, #T_f717e_row14_col0, #T_f717e_row14_col1, #T_f717e_row14_col2, #T_f717e_row14_col3, #T_f717e_row15_col0, #T_f717e_row15_col1, #T_f717e_row15_col2, #T_f717e_row15_col3 {
#   text-align: center;
# }
# #T_f717e_row0_col4, #T_f717e_row0_col5, #T_f717e_row1_col4, #T_f717e_row1_col5, #T_f717e_row2_col4, #T_f717e_row2_col5, #T_f717e_row3_col4, #T_f717e_row3_col5, #T_f717e_row4_col4, #T_f717e_row4_col5, #T_f717e_row5_col4, #T_f717e_row5_col5, #T_f717e_row6_col4, #T_f717e_row6_col5, #T_f717e_row7_col4, #T_f717e_row7_col5, #T_f717e_row8_col4, #T_f717e_row8_col5, #T_f717e_row9_col4, #T_f717e_row9_col5, #T_f717e_row10_col4, #T_f717e_row10_col5, #T_f717e_row11_col4, #T_f717e_row11_col5, #T_f717e_row12_col4, #T_f717e_row12_col5, #T_f717e_row13_col4, #T_f717e_row13_col5, #T_f717e_row14_col4, #T_f717e_row14_col5, #T_f717e_row15_col4, #T_f717e_row15_col5 {
#   background-color: #90ee90;
#   text-align: center;
# }
# </style>
# <table id="T_f717e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f717e_level0_col0" class="col_heading level0 col0" >constraint</th>
#       <th id="T_f717e_level0_col1" class="col_heading level0 col1" >structure_name</th>
#       <th id="T_f717e_level0_col2" class="col_heading level0 col2" >Limit</th>
#       <th id="T_f717e_level0_col3" class="col_heading level0 col3" >Goal</th>
#       <th id="T_f717e_level0_col4" class="col_heading level0 col4" >Plan Value 0</th>
#       <th id="T_f717e_level0_col5" class="col_heading level0 col5" >Plan Value 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f717e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f717e_row0_col0" class="data row0 col0" >max_dose</td>
#       <td id="T_f717e_row0_col1" class="data row0 col1" >GTV</td>
#       <td id="T_f717e_row0_col2" class="data row0 col2" >69.0Gy</td>
#       <td id="T_f717e_row0_col3" class="data row0 col3" >66.0Gy</td>
#       <td id="T_f717e_row0_col4" class="data row0 col4" >61.88</td>
#       <td id="T_f717e_row0_col5" class="data row0 col5" >60.84</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f717e_row1_col0" class="data row1 col0" >max_dose</td>
#       <td id="T_f717e_row1_col1" class="data row1 col1" >PTV</td>
#       <td id="T_f717e_row1_col2" class="data row1 col2" >69.0Gy</td>
#       <td id="T_f717e_row1_col3" class="data row1 col3" >66.0Gy</td>
#       <td id="T_f717e_row1_col4" class="data row1 col4" >63.46</td>
#       <td id="T_f717e_row1_col5" class="data row1 col5" >62.15</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f717e_row2_col0" class="data row2 col0" >max_dose</td>
#       <td id="T_f717e_row2_col1" class="data row2 col1" >ESOPHAGUS</td>
#       <td id="T_f717e_row2_col2" class="data row2 col2" >66.0Gy</td>
#       <td id="T_f717e_row2_col3" class="data row2 col3" ></td>
#       <td id="T_f717e_row2_col4" class="data row2 col4" >11.39</td>
#       <td id="T_f717e_row2_col5" class="data row2 col5" >9.41</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f717e_row3_col0" class="data row3 col0" >mean_dose</td>
#       <td id="T_f717e_row3_col1" class="data row3 col1" >ESOPHAGUS</td>
#       <td id="T_f717e_row3_col2" class="data row3 col2" >34.0Gy</td>
#       <td id="T_f717e_row3_col3" class="data row3 col3" >21.0Gy</td>
#       <td id="T_f717e_row3_col4" class="data row3 col4" >1.45</td>
#       <td id="T_f717e_row3_col5" class="data row3 col5" >1.43</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f717e_row4_col0" class="data row4 col0" >V(60.0Gy)</td>
#       <td id="T_f717e_row4_col1" class="data row4 col1" >ESOPHAGUS</td>
#       <td id="T_f717e_row4_col2" class="data row4 col2" >17.0%</td>
#       <td id="T_f717e_row4_col3" class="data row4 col3" ></td>
#       <td id="T_f717e_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_f717e_row4_col5" class="data row4 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f717e_row5_col0" class="data row5 col0" >max_dose</td>
#       <td id="T_f717e_row5_col1" class="data row5 col1" >HEART</td>
#       <td id="T_f717e_row5_col2" class="data row5 col2" >66.0Gy</td>
#       <td id="T_f717e_row5_col3" class="data row5 col3" ></td>
#       <td id="T_f717e_row5_col4" class="data row5 col4" >43.47</td>
#       <td id="T_f717e_row5_col5" class="data row5 col5" >45.28</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f717e_row6_col0" class="data row6 col0" >mean_dose</td>
#       <td id="T_f717e_row6_col1" class="data row6 col1" >HEART</td>
#       <td id="T_f717e_row6_col2" class="data row6 col2" >27.0Gy</td>
#       <td id="T_f717e_row6_col3" class="data row6 col3" >20.0Gy</td>
#       <td id="T_f717e_row6_col4" class="data row6 col4" >3.42</td>
#       <td id="T_f717e_row6_col5" class="data row6 col5" >3.56</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f717e_row7_col0" class="data row7 col0" >V(30.0Gy)</td>
#       <td id="T_f717e_row7_col1" class="data row7 col1" >HEART</td>
#       <td id="T_f717e_row7_col2" class="data row7 col2" >50.0%</td>
#       <td id="T_f717e_row7_col3" class="data row7 col3" ></td>
#       <td id="T_f717e_row7_col4" class="data row7 col4" >0.28</td>
#       <td id="T_f717e_row7_col5" class="data row7 col5" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f717e_row8_col0" class="data row8 col0" >V(30.0Gy)</td>
#       <td id="T_f717e_row8_col1" class="data row8 col1" >HEART</td>
#       <td id="T_f717e_row8_col2" class="data row8 col2" ></td>
#       <td id="T_f717e_row8_col3" class="data row8 col3" >48.0%</td>
#       <td id="T_f717e_row8_col4" class="data row8 col4" >0.28</td>
#       <td id="T_f717e_row8_col5" class="data row8 col5" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f717e_row9_col0" class="data row9 col0" >max_dose</td>
#       <td id="T_f717e_row9_col1" class="data row9 col1" >LUNG_L</td>
#       <td id="T_f717e_row9_col2" class="data row9 col2" >66.0Gy</td>
#       <td id="T_f717e_row9_col3" class="data row9 col3" ></td>
#       <td id="T_f717e_row9_col4" class="data row9 col4" >11.45</td>
#       <td id="T_f717e_row9_col5" class="data row9 col5" >10.86</td>
#     </tr>
#     <tr>
#       <th id="T_f717e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f717e_row10_col0" class="data row10 col0" >max_dose</td>
#       <td id="T_f717e_row10_col1" class="data row10 col1" >LUNG_R</td>
#       <td id="T_f717e_row10_col2" class="data row10
